# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(2016,2024)
y = np.array([77, 87, 79, 87, 95, 120, 257, 215])
print(x)
print(y)
plt.grid()
plt.title("Результаты поиска статей на сайте Elibrary.ru по запросу 'RRAM'")
plt.plot(x,y)
plt.show()
x = np.arange(2016,2024)
y = np.array([908, 1080, 1250, 1440, 1640, 2010, 2270, 2460])
print(x)
print(y)
plt.grid()
plt.title("Результаты поиска статей на сайте scholar.google.ru по запросу 'modeling RRAM'")
plt.plot(x,y)
plt.show()
# Out:
# [2016 2017 2018 2019 2020 2021 2022 2023]
# [ 77  87  79  87  95 120 257 215]
# [2016 2017 2018 2019 2020 2021 2022 2023]
# [ 908 1080 1250 1440 1640 2010 2270 2460]

# %% [markdown]
# # Первый график
# Рост можно объяснить развитием направления резестивной памяти, а именно изучением новых элементов и использованием новых методик для объяснения процесса/получения данных. Также можно связать рост с быстрым развитием машинного обучения, где мемристоры играют важную роль в построении аналоговых архитектур искусственных нейроных сетей.  Спад в 2023 году символизирует о том, что некоторые принципы в исследовании RAM стали неактуальными.
# # Второй график
# Здесь же мы выделили единую тематикe исследование, наблюдается монотонный рост публикаций по теме "modeling RRAM", что объясняется теми же аргементами, что и выше
