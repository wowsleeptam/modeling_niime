# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(2016,2024)
y = np.array([77, 87, 79, 87, 95, 120, 257, 215])
print(x)
print(y)
plt.grid()
plt.plot(x,y)
plt.title("Результаты поиска статей на сайте Elibrary.ru по запросу RRAM")
# Out:
# [2016 2017 2018 2019 2020 2021 2022 2023]
# [ 77  87  79  87  95 120 257 215]
# Text(0.5, 1.0, 'Результаты поиска статей на сайте Elibrary.ru по запросу RRAM')
